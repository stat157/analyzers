# %% [markdown]
# **Imports the necessary packages**

# %%
import datetime
import time
import urllib
import numpy as np
import pandas as pd
from pandas import read_csv
from dateutil import parser
from pprint import pprint

# %% [markdown]
# **Use the data from the curators, populate a Pandas dataframe**

# %%
# This is the 2013 data from the curators
# Thanks Piazza for the free hosting :p

# We'll probably have to setup a github page for this project, or find a more 
# reliable way to host our csv file later
data = read_csv("https://piazza.com/class_profile/get_resource/hkyfvggfat84vl/hnnxl94gqitqb")
clean_data = data.dropna(axis=0, how='any')
test_data = clean_data[0:20]
test_data
# Out:
#     YYYY/MM/DD  HH:mm:SS.ss  ET   MAG  M     LAT      LON  DEPTH  Q      EVID  \
# 0   2013/01/01  00:55:30.86  le  0.75  l  33.973 -116.807   13.9  A  15269305
# 1   2013/01/01  01:22:48.22  le  1.61  l  34.909 -119.596   10.0  A  15269313
# 2   2013/01/01  01:30:15.24  le  0.28  l  35.946 -117.662    5.0  A  15269321
# 3   2013/01/01  01:50:54.74  le  0.64  l  33.704 -116.751   19.5  A  15269329
# 4   2013/01/01  02:00:11.27  le  0.83  l  33.276 -116.780   13.0  A  15269337
# 5   2013/01/01  02:47:58.48  le  1.87  l  33.782 -118.358    8.2  A  15269353
# 6   2013/01/01  03:01:55.10  le  1.13  l  34.177 -117.364   12.8  A  15269361
# 7   2013/01/01  03:29:39.68  le  1.66  l  36.155 -118.064    0.5  A  15269369
# 8   2013/01/01  06:10:05.13  le  1.01  l  36.151 -118.073    5.6  C  15269377
# 9   2013/01/01  06:36:26.07  le  0.67  l  33.658 -116.733   15.7  A  15269385
# 10  2013/01/01  06:36:57.02  le  1.27  l  35.034 -119.119   24.8  A  15269393
# 11  2013/01/01  07:56:44.21  le  0.86  l  33.964 -117.208   15.2  A  15269409
# 12  2013/01/01  08:37:23.12  le  0.87  l  33.098 -116.476   11.2  A  15269417
# 13  2013/01/01  09:00:56.43  le  1.19  l  35.155 -118.583    9.5  A  15269425
# 14  2013/01/01  09:52:34.96  le  0.53  l  33.527 -116.416   12.2  A  15269433
# 15  2013/01/01  11:16:09.07  le  0.00  h  36.110 -117.671    4.8  B  37106291
# 16  2013/01/01  11:16:09.26  le  1.81  l  36.102 -117.668    1.5  A  15269441
# 17  2013/01/01  11:32:01.81  le  0.78  l  33.025 -116.434    5.1  C  15269449
# 18  2013/01/01  12:32:24.47  le  1.00  l  32.977 -116.746   14.9  A  15269457
# 19  2013/01/01  13:48:33.32  re  2.04  l  36.094 -119.918    6.0  C  15269465
#
#     NPH  NGRM
# 0    32     0
# 1    27     0
# 2     9     0
# 3    18     0
# 4    36     0
# 5    59     0
# 6    54     0
# 7    38     0
# 8    14     0
# 9    38     0
# 10   21     0
# 11   27     0
# 12   32     0
# 13   25     0
# 14   32     0
# 15    7     0
# 16   35     0
# 17   45     0
# 18   24     0
# 19   12     0

# %% [markdown]
# **Get some relevant data using the first two columns (date and time), and the 'MAG' column (Magnitude)**

# %%
test_mag = test_data['MAG']
test_mag = test_mag.tolist()
test_mag
# Out:
# [0.75,
#  1.61,
#  0.28,
#  0.64,
#  0.83,
#  1.87,
#  1.13,
#  1.66,
#  1.01,
#  0.67,
#  1.27,
#  0.86,
#  0.87,
#  1.19,
#  0.53,
#  0.0,
#  1.81,
#  0.78,
#  1.0,
#  2.04]

# %%
test_date = test_data['YYYY/MM/DD']
test_time = test_data['HH:mm:SS.ss']

test_dt = [parser.parse(date + " " + time) for date, time in zip(test_date, test_time)]
test_dt
# Out:
# [datetime.datetime(2013, 1, 1, 0, 55, 30, 860000),
#  datetime.datetime(2013, 1, 1, 1, 22, 48, 220000),
#  datetime.datetime(2013, 1, 1, 1, 30, 15, 240000),
#  datetime.datetime(2013, 1, 1, 1, 50, 54, 740000),
#  datetime.datetime(2013, 1, 1, 2, 0, 11, 270000),
#  datetime.datetime(2013, 1, 1, 2, 47, 58, 480000),
#  datetime.datetime(2013, 1, 1, 3, 1, 55, 100000),
#  datetime.datetime(2013, 1, 1, 3, 29, 39, 680000),
#  datetime.datetime(2013, 1, 1, 6, 10, 5, 130000),
#  datetime.datetime(2013, 1, 1, 6, 36, 26, 70000),
#  datetime.datetime(2013, 1, 1, 6, 36, 57, 20000),
#  datetime.datetime(2013, 1, 1, 7, 56, 44, 210000),
#  datetime.datetime(2013, 1, 1, 8, 37, 23, 120000),
#  datetime.datetime(2013, 1, 1, 9, 0, 56, 430000),
#  datetime.datetime(2013, 1, 1, 9, 52, 34, 960000),
#  datetime.datetime(2013, 1, 1, 11, 16, 9, 70000),
#  datetime.datetime(2013, 1, 1, 11, 16, 9, 260000),
#  datetime.datetime(2013, 1, 1, 11, 32, 1, 810000),
#  datetime.datetime(2013, 1, 1, 12, 32, 24, 470000),
#  datetime.datetime(2013, 1, 1, 13, 48, 33, 320000)]

# %% [markdown]
# **Extracts the alarm length for each possible quake**

# %%
def mda(mag, dt):
    """
    Uses basic MDA model (tau*u^mag) to predict earthquakes.
    Returns tuple of (start, end) representing date range when alarm should be on.
    MAG: list of earthquake magnitudes
    DT: list of earthquake datetimes in python datetime format
    (MAG and DT have the same length and come from earthquakes data frame)
    """
    assert len(mag) == len(dt), "Dude are you mad?"
    
    tau = 0.7 # we will figure out what tau is later
    u = 4 # we will add fancy tuning functionality later
    alarms = []
    
    for i in range(0, len(mag)):
        alarm_length = tau * (u ** mag[i])
        val = datetime.timedelta(seconds=alarm_length)
        rng = (dt[i], dt[i]+val)
        alarms.append(rng)
    return alarms

# %%
alarm_ranges = mda(test_mag, test_dt)
alarm_ranges
# Out:
# [(datetime.datetime(2013, 1, 1, 0, 55, 30, 860000),
#   datetime.datetime(2013, 1, 1, 0, 55, 32, 839899)),
#  (datetime.datetime(2013, 1, 1, 1, 22, 48, 220000),
#   datetime.datetime(2013, 1, 1, 1, 22, 54, 742508)),
#  (datetime.datetime(2013, 1, 1, 1, 30, 15, 240000),
#   datetime.datetime(2013, 1, 1, 1, 30, 16, 271988)),
#  (datetime.datetime(2013, 1, 1, 1, 50, 54, 740000),
#   datetime.datetime(2013, 1, 1, 1, 50, 56, 439873)),
#  (datetime.datetime(2013, 1, 1, 2, 0, 11, 270000),
#   datetime.datetime(2013, 1, 1, 2, 0, 13, 482116)),
#  (datetime.datetime(2013, 1, 1, 2, 47, 58, 480000),
#   datetime.datetime(2013, 1, 1, 2, 48, 7, 832985)),
#  (datetime.datetime(2013, 1, 1, 3, 1, 55, 100000),
#   datetime.datetime(2013, 1, 1, 3, 1, 58, 452940)),
#  (datetime.datetime(2013, 1, 1, 3, 29, 39, 680000),
#   datetime.datetime(2013, 1, 1, 3, 29, 46, 670651)),
#  (datetime.datetime(2013, 1, 1, 6, 10, 5, 130000),
#   datetime.datetime(2013, 1, 1, 6, 10, 7, 969087)),
#  (datetime.datetime(2013, 1, 1, 6, 36, 26, 70000),
#   datetime.datetime(2013, 1, 1, 6, 36, 27, 842059)),
#  (datetime.datetime(2013, 1, 1, 6, 36, 57, 20000),
#   datetime.datetime(2013, 1, 1, 6, 37, 1, 91123)),
#  (datetime.datetime(2013, 1, 1, 7, 56, 44, 210000),
#   datetime.datetime(2013, 1, 1, 7, 56, 46, 516055)),
#  (datetime.datetime(2013, 1, 1, 8, 37, 23, 120000),
#   datetime.datetime(2013, 1, 1, 8, 37, 25, 458246)),
#  (datetime.datetime(2013, 1, 1, 9, 0, 56, 430000),
#   datetime.datetime(2013, 1, 1, 9, 1, 0, 73757)),
#  (datetime.datetime(2013, 1, 1, 9, 52, 34, 960000),
#   datetime.datetime(2013, 1, 1, 9, 52, 36, 419452)),
#  (datetime.datetime(2013, 1, 1, 11, 16, 9, 70000),
#   datetime.datetime(2013, 1, 1, 11, 16, 9, 770000)),
#  (datetime.datetime(2013, 1, 1, 11, 16, 9, 260000),
#   datetime.datetime(2013, 1, 1, 11, 16, 17, 866501)),
#  (datetime.datetime(2013, 1, 1, 11, 32, 1, 810000),
#   datetime.datetime(2013, 1, 1, 11, 32, 3, 873977)),
#  (datetime.datetime(2013, 1, 1, 12, 32, 24, 470000),
#   datetime.datetime(2013, 1, 1, 12, 32, 27, 270000)),
#  (datetime.datetime(2013, 1, 1, 13, 48, 33, 320000),
#   datetime.datetime(2013, 1, 1, 13, 48, 45, 158602))]

# %%
data_we_need = {'Latitude': test_data['LAT'], 'Longitude': test_data['LON'], 
                'Alarm Begins': [alarm[0] for alarm in alarm_ranges], 
                'Alarm Ends': [alarm[1] for alarm in alarm_ranges]}
dframe = pd.DataFrame(data_we_need)
dframe
# Out:
#                  Alarm Begins                 Alarm Ends  Latitude  Longitude
# 0  2013-01-01 00:55:30.860000 2013-01-01 00:55:32.839899    33.973   -116.807
# 1  2013-01-01 01:22:48.220000 2013-01-01 01:22:54.742508    34.909   -119.596
# 2  2013-01-01 01:30:15.240000 2013-01-01 01:30:16.271988    35.946   -117.662
# 3  2013-01-01 01:50:54.740000 2013-01-01 01:50:56.439873    33.704   -116.751
# 4  2013-01-01 02:00:11.270000 2013-01-01 02:00:13.482116    33.276   -116.780
# 5  2013-01-01 02:47:58.480000 2013-01-01 02:48:07.832985    33.782   -118.358
# 6  2013-01-01 03:01:55.100000 2013-01-01 03:01:58.452940    34.177   -117.364
# 7  2013-01-01 03:29:39.680000 2013-01-01 03:29:46.670651    36.155   -118.064
# 8  2013-01-01 06:10:05.130000 2013-01-01 06:10:07.969087    36.151   -118.073
# 9  2013-01-01 06:36:26.070000 2013-01-01 06:36:27.842059    33.658   -116.733
# 10 2013-01-01 06:36:57.020000 2013-01-01 06:37:01.091123    35.034   -119.119
# 11 2013-01-01 07:56:44.210000 2013-01-01 07:56:46.516055    33.964   -117.208
# 12 2013-01-01 08:37:23.120000 2013-01-01 08:37:25.458246    33.098   -116.476
# 13 2013-01-01 09:00:56.430000 2013-01-01 09:01:00.073757    35.155   -118.583
# 14 2013-01-01 09:52:34.960000 2013-01-01 09:52:36.419452    33.527   -116.416
# 15 2013-01-01 11:16:09.070000 2013-01-01 11:16:09.770000    36.110   -117.671
# 16 2013-01-01 11:16:09.260000 2013-01-01 11:16:17.866501    36.102   -117.668
# 17 2013-01-01 11:32:01.810000 2013-01-01 11:32:03.873977    33.025   -116.434
# 18 2013-01-01 12:32:24.470000 2013-01-01 12:32:27.270000    32.977   -116.746
# 19 2013-01-01 13:48:33.320000 2013-01-01 13:48:45.158602    36.094   -119.918
